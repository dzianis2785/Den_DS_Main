# %%
import pandas as pd
melb_df = pd.read_csv("data/melb_data_fe.csv")
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
display(melb_df['Date'])
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
# ...

# %%
year_quarter = melb_df['Date'].dt.quarter
display(year_quarter)
# Out:
# 0        1
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    3
# 13576    3
# 13577    3
# 13578    3
# 13579    3
# Name: Date, Length: 13580, dtype: int32

# %%
year_quarter.value_counts()
# Out:
# Date
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: count, dtype: int64

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] 
max_unique_count = 150 
for col in melb_df.columns: 
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: 
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.sort_values(by='Price', ascending = False).head(10)
# Out:
#             Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 12094        other      3  house  9000000.0     PI     other 2017-07-29
# 7692    Canterbury      5  house  8000000.0     VB     other 2017-05-13
# 9575      Hawthorn      4  house  7650000.0      S     other 2017-06-17
# 3616           Kew      6  house  6500000.0      S    Jellis 2016-08-13
# 12557  Middle Park      5  house  6400000.0      S  Marshall 2017-09-09
# 6372        Toorak      3  house  6250000.0      S       Kay 2016-10-15
# 7554      Brighton      5  house  5800000.0     PI     other 2017-08-04
# 5631   South Yarra      4  house  5700000.0      S     other 2016-12-11
# 9233   Middle Park      6  house  5600000.0     PI  Marshall 2017-03-06
# 251       Armadale      6  house  5525000.0      S  Marshall 2016-09-17
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# 12094      18.8      3170        3  ...   145.16126
# 7692        9.0      3126        5  ...   145.06940
# ...

# %%
melb_df.sort_values(by='Date')
# Out:
#                Suburb  Rooms       Type      Price Method        SellerG  \
# 6183     Surrey Hills      2       unit   813000.0      S      Fletchers
# 6184     Surrey Hills      3      house  1205000.0      S      Fletchers
# 788    Bentleigh East      3  townhouse   760000.0     PI  hockingstuart
# 3821     Malvern East      4      house  1675000.0     PI        Thomson
# 4008      Middle Park      3      house  2600000.0     VB         Cayzer
# ...               ...    ...        ...        ...    ...            ...
# 10999           other      4      house   762000.0      S         Jellis
# 10998           other      3      house   830000.0     VB          other
# 10997           other      2       unit  1300000.0     SP          other
# 11019           other      3      house   904000.0     SP          other
# 11261      Yarraville      3      house   920000.0     PI        Village
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %%
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 2652        6.4    85000.0
# 7116        7.8   200000.0
# 5206       11.2   220000.0
# 7240        8.2   241000.0
# 2898       13.0   250000.0
# ...         ...        ...
# 13341       6.3  4060000.0
# 8591        1.5  4275000.0
# 1094       11.2  4700000.0
# 5801        6.1  5046000.0
# 251         6.3  5525000.0
#
# [1358 rows x 2 columns]

# %%
melb_df.sort_values(by=['Price', 'Distance']).loc[::10, ['Price', 'Distance']]
# Out:
#            Price  Distance
# 2652     85000.0       6.4
# 7116    200000.0       7.8
# 5206    220000.0      11.2
# 7240    241000.0       8.2
# 2898    250000.0      13.0
# ...          ...       ...
# 13341  4060000.0       6.3
# 8591   4275000.0       1.5
# 1094   4700000.0      11.2
# 5801   5046000.0       6.1
# 251    5525000.0       6.3
#
# [1358 rows x 2 columns]

# %%
melb_df.sort_values(by=['AreaRatio'], ignore_index=True).loc[1557, 'BuildingArea']
# Out:
# 126.0

# %%
filtered = melb_df[(melb_df['Type'] == 'townhouse') & (melb_df['Rooms'] > 2)]
display(filtered)
# Out:
#                Suburb  Rooms       Type      Price Method   SellerG  \
# 21         Abbotsford      3  townhouse   900000.0      S     other
# 38       Airport West      3  townhouse   840000.0     PI    Nelson
# 42       Airport West      3  townhouse   700000.0      S      Brad
# 56       Airport West      3  townhouse   700000.0     PI      Brad
# 67       Airport West      3  townhouse   540000.0     SP    Nelson
# ...               ...    ...        ...        ...    ...       ...
# 13437           other      4  townhouse   655000.0      S    Nelson
# 13485           other      4  townhouse  1655000.0      S    Buxton
# 13504  Mount Waverley      3  townhouse  1035000.0     SP   McGrath
# 13521  Port Melbourne      4  townhouse  2455000.0     SP  Marshall
# 13526       Reservoir      3  townhouse   640000.0     PI       Ray
#
#             Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# 21    2017-03-18       2.5      3067        3  ...   144.99590
# ...

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
new_filtered = filtered.sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True,False], ignore_index=True).copy()
display(new_filtered)
# Out:
#              Suburb  Rooms       Type      Price Method        SellerG  \
# 0             other      3  townhouse  1900000.0     PI          other
# 1          Brighton      3  townhouse  3275000.0     SP       Marshall
# 2      Moonee Ponds      3  townhouse  1345000.0     SP          Barry
# 3         Ashburton      3  townhouse  2050000.0      S      Fletchers
# 4        Strathmore      3  townhouse   925000.0      S          other
# ..              ...    ...        ...        ...    ...            ...
# 779    Moonee Ponds      5  townhouse   980000.0     PI         Nelson
# 780         Glenroy      5  townhouse   645000.0      S          Barry
# 781       Chadstone      5  townhouse  1050000.0      S         Buxton
# 782     Maribyrnong      5  townhouse  1000000.0     PI          other
# 783  Doncaster East      5  townhouse  1500000.0     SP  hockingstuart
#
#           Date  Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
print(new_filtered.loc[17:19, 'Price'])
# Out:
# 17    1320000.0
# 18    1300000.0
# 19    2700000.0
# Name: Price, dtype: float64

# %%
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/2774055988.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# ...

# %%
melb_df.groupby(by='Type', as_index=False).mean(numeric_only=True)
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/2099806448.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type', as_index=False).mean(numeric_only=True)
#         Type     Rooms         Price   Distance     Postcode   Bedroom  \
# 0      house  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# 1  townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# 2       unit  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#    Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# 0  1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# 1  1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# 2  1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
# ...

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/2328732824.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/3783769093.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/3700124206.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/701566850.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe')
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# ...

# %%
melb_df.groupby('Regionname')['SellerG'].agg(['nunique', set])
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/4026196115.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['SellerG'].agg(['nunique', set])
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Fletchers, other, Harcourts, C21, McGrath, Bi...
# Eastern Victoria            {hockingstuart, Ray, Fletchers, HAR, other, Ha...
# ...

# %%
melb_df.groupby('Rooms')['Price'].mean().sort_values()
# Out:
# Rooms
# 1     4.338245e+05
# 2     7.750812e+05
# 10    9.000000e+05
# 3     1.076081e+06
# 4     1.445282e+06
# 8     1.602750e+06
# 6     1.849366e+06
# 5     1.870260e+06
# 7     1.920700e+06
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/2833887339.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
melb_df['Date'].dt.date
date_year = melb_df[(melb_df['Date'] > '2017-04-30') & (melb_df['Date'] < "2017-09-02")]
display(date_year)
# Out:
#              Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 7431     Aberfeldie      4  house  1330000.0      S    Nelson 2017-06-05
# 7432     Aberfeldie      3  house  1300000.0      S    Nelson 2017-08-04
# 7433     Aberfeldie      2  house   470000.0      S     Barry 2017-08-04
# 7435    Albert Park      3  house  1700000.0     VB      Greg 2017-06-05
# 7436    Albert Park      1   unit  1100000.0     PI    Nelson 2017-08-04
# ...             ...    ...    ...        ...    ...       ...        ...
# 13575         other      4  house  1245000.0      S     Barry 2017-08-26
# 13576  Williamstown      3  house  1031000.0     SP  Williams 2017-08-26
# 13577  Williamstown      3  house  1170000.0      S     Raine 2017-08-26
# 13578  Williamstown      4  house  2500000.0     PI   Sweeney 2017-08-26
# 13579    Yarraville      4  house  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# ...

# %%
display(date_year.groupby('SellerG')['Price'].sum().sort_values())
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/2753198907.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   display(date_year.groupby('SellerG')['Price'].sum().sort_values())
# SellerG
# LITTLE             2742000.0
# Cayzer             4439000.0
# Burnham            4550500.0
# Moonee             7328000.0
# Thomson            8332000.0
# Bells              8656000.0
# Alexkarbon        10985000.0
# McDonald          14637500.0
# Rendina           15422276.0
# Nick              16890000.0
# Douglas           18341000.0
# Buckingham        19033000.0
# C21               19515000.0
# Eview             19791500.0
# Collins           20217000.0
# Philip            22051800.0
# Chisholm          23225000.0
# Williams          23297000.0
# Love              23365500.0
# ...

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/1672652905.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/1672652905.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(

# %%
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
data_set = melb_df.pivot_table(
    values='Price',
    index='SellerG', 
    columns='Type',
    aggfunc='median',
    fill_value=0
)
display(data_set)
# Out:
# /var/folders/k8/80n4td7d33q9fs3mzc27yjfr0000gn/T/ipykernel_41088/2701959724.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data_set = melb_df.pivot_table(
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        0.0  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# ...

# %%
display(data_set.sort_values(by='unit'))
# Out:
# Type               house  townhouse      unit
# SellerG
# Burnham         922500.0        0.0  305000.0
# Sweeney         850000.0   728000.0  381000.0
# Stockdale       715500.0   550000.0  410000.0
# Village         973500.0   727500.0  420000.0
# Love            780000.0   846000.0  440000.0
# YPA             596250.0   498500.0  443500.0
# LITTLE          970000.0   800000.0  447000.0
# Raine           745000.0   608000.0  447500.0
# Jas             935000.0   699000.0  455000.0
# Bells           692500.0   430500.0  457500.0
# Rendina        1190000.0   750000.0  459000.0
# Brad            875000.0   700000.0  465000.0
# Douglas         684000.0   500000.0  494500.0
# Thomson        1177000.0   500000.0  495000.0
# Ray             900000.0   650000.0  497500.0
# Harcourts       740000.0   653750.0  500000.0
# Barry           830000.0   727500.0  502000.0
# McDonald       1242500.0        0.0  502500.0
# HAR             695000.0        0.0  518000.0
# ...

# %%
table1 = pd.read_csv('data/movies_data/ratings1.csv')
display(table1)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 39996     274     5582     2.5
# 39997     274     5585     3.5
# 39998     274     5588     3.5
# 39999     274     5618     4.0
# 40000     274     5621     2.0
#
# [40001 rows x 3 columns]

# %%
table2 = pd.read_csv('data/movies_data/ratings2.csv')
display(table2)
# Out:
#        userId  movieId  rating
# 0         274     5621     2.0
# 1         274     5630     3.0
# 2         274     5667     3.5
# 3         274     5679     3.5
# 4         274     5690     3.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [60836 rows x 3 columns]

# %%
movies = pd.read_csv('data/movies_data/movies.csv')
display(movies)
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
movies.nunique()
# Out:
# movieId    9742
# title      9737
# genres      951
# dtype: int64

# %%
table1.nunique()
# Out:
# userId      274
# movieId    6219
# rating       10
# dtype: int64

# %%
table2.nunique()
# Out:
# userId      337
# movieId    8567
# rating       10
# dtype: int64

# %%
date_tables = pd.read_csv('data/movies_data/dates.csv')
display(date_tables.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    100836 non-null  object
# dtypes: object(1)
# memory usage: 787.9+ KB
# None

# %%
display(date_tables)
# Out:
#                        date
# 0       2000-07-30 18:45:03
# 1       2000-07-30 18:20:47
# 2       2000-07-30 18:37:04
# 3       2000-07-30 19:03:35
# 4       2000-07-30 18:48:51
# ...                     ...
# 100831  2017-05-03 21:53:22
# 100832  2017-05-03 22:21:31
# 100833  2017-05-08 19:50:47
# 100834  2017-05-03 21:19:12
# 100835  2017-05-03 21:20:15
#
# [100836 rows x 1 columns]

# %%
date_tables['date']= pd.to_datetime(date_tables['date'], dayfirst=False)
display(date_tables.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    100836 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 787.9 KB
# None

# %%
display(date_tables['date'].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 100836 entries, 0 to 100835
# Series name: date
# Non-Null Count   Dtype
# --------------   -----
# 100836 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 787.9 KB
# None

# %%
date = date_tables['date'].dt.year

# %%
display(date.value_counts())
# Out:
# date
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: count, dtype: int64

# %%
ratings = pd.concat([table1, table2])
display(ratings)
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 60831     610   166534     4.0
# 60832     610   168248     5.0
# 60833     610   168250     5.0
# 60834     610   168252     5.0
# 60835     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
ratings = pd.concat(
    [table1, table2],
    ignore_index=True
)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице date_tables: ', date_tables.shape[0])
print(ratings.shape[0] == date_tables.shape[0])
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице date_tables:  100836
# False

# %%
display(table1.tail(1))
display(table2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)
print('Число строк в таблице ratings: ', ratings.shape[0])
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, date_tables], axis=1)
display(ratings_dates.tail(7))
# Out:
#         userId  movieId  rating                date
# 100829     610   164179     5.0 2017-05-03 21:07:11
# 100830     610   166528     4.0 2017-05-04 06:29:25
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15

# %%
display(ratings_dates)
# Out:
#         userId  movieId  rating                date
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
# [100836 rows x 4 columns]

# %%
display(movies)
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03            1.0
# 1            1        3     4.0 2000-07-30 18:20:47            2.0
# 2            1        6     4.0 2000-07-30 18:37:04            3.0
# 3            1       47     5.0 2000-07-30 19:03:35            4.0
# 4            1       50     5.0 2000-07-30 18:48:51            5.0
# ...        ...      ...     ...                 ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# ...

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined)
# Out:
#         userId  movieId  rating                date  \
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# 3          Seven (a.k.a. Se7en) (1995)
# 4           Usual Suspects, The (1995)
# ...                                ...
# 100831                    Split (2017)
# ...

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date                        title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story (1995)
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men (1995)
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat (1995)
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
import pandas as pd

items_df = pd.DataFrame({
            'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394],
            'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
            'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
        })

purchase_df = pd.DataFrame({
            'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
            'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132],
            'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
        })
display(items_df)
display(purchase_df)

merged = items_df.merge(purchase_df, on='item_id', how='inner')
display(merged)
# Out:
#    item_id   vendor  stock_count
# 0   417283  Samsung           54
# 1   849734       LG           33
# 2   132223    Apple          122
# 3   573943    Apple           18
# 4    19475       LG          102
# 5  3294095    Apple           43
# 6   382043  Samsung           77
# 7   302948  Samsung          143
# 8   100132       LG           60
# 9   312394      ZTE           19
#    purchase_id  item_id  price
# 0          101   417283  13900
# 1          101   849734   5330
# 2          101   132223  38200
# 3          112   573943  49990
# 4          121    19475   9890
# 5          145  3294095  33000
# 6          145   382043  67500
# 7          145   302948  34500
# 8          145   103845  89900
# 9          221   100132  11400
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# ...

# %%
merged['stock_count'].loc[0]
# Out:
# 54

# %%
print(list(merged.index))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
income = 0
for index in list(merged.index):
    income = income + ((merged['stock_count'][index]) * (merged['price'][index])) 
print(income)
# Out:
# 19729490
