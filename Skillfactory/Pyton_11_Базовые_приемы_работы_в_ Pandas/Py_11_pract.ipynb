# %%
import pandas as pd
citibike_tripdata = pd.read_csv('data/citibike-tripdata.csv', sep=',')
display(citibike_tripdata)
# Out:
#                        starttime                  stoptime  start station id  \
# 0       2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1       2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2       2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3       2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4       2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
# ...                          ...                       ...               ...
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940             494.0
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080            3016.0
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060            3686.0
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220             254.0
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620            3496.0
#
# ...

# %%
citibike_tripdata = citibike_tripdata.copy()

# %%
display(citibike_tripdata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
citibike_tripdata['start station id'].value_counts()
# Out:
# start station id
# 281.0     1928
# 2006.0    1909
# 519.0     1873
# 514.0     1845
# 426.0     1835
#           ...
# 3432.0      15
# 3599.0      11
# 2005.0       9
# 3704.0       7
# 3583.0       6
# Name: count, Length: 759, dtype: int64

# %%
citibike_tripdata['bikeid'].value_counts()
# Out:
# bikeid
# 33887    107
# 34358    104
# 34159    103
# 34258    103
# 33916    102
#         ...
# 18587      1
# 17324      1
# 29593      1
# 33157      1
# 25794      1
# Name: count, Length: 10004, dtype: int64

# %%
citibike_tripdata['usertype'].value_counts(normalize=True)
# Out:
# usertype
# Subscriber    0.774007
# Customer      0.225993
# Name: proportion, dtype: float64

# %%
print(citibike_tripdata['gender'].value_counts())
# Out:
# gender
# 1    183582
# 2     74506
# 0     41912
# Name: count, dtype: int64

# %%
print(citibike_tripdata['start station id'].nunique())
print(citibike_tripdata['end station id'].nunique())
# Out:
# 759
# 765

# %%
print(citibike_tripdata['birth year'].max())
# Out:
# 2002

# %%
print(citibike_tripdata['start station name'].value_counts())
# Out:
# start station name
# Grand Army Plaza & Central Park S    1928
# Central Park S & 6 Ave               1909
# Pershing Square North                1873
# 12 Ave & W 40 St                     1845
# West St & Chambers St                1835
#                                      ...
# NYCBS Depot - GOW                      15
# Franklin Ave & Empire Blvd             11
# Railroad Ave & Kay Ave                  9
# 47 Ave & Skillman Ave                   7
# Eastern Pkwy & Washington Ave           6
# Name: count, Length: 759, dtype: int64

# %%
print(citibike_tripdata['end station name'].value_counts())
# Out:
# end station name
# West St & Chambers St          1963
# 12 Ave & W 40 St               1909
# Pershing Square North          1850
# Central Park S & 6 Ave         1828
# E 17 St & Broadway             1804
#                                ...
# Exchange Place                    3
# Union St                          1
# Warren St                         1
# Montrose Ave & Bushwick Ave       1
# Liberty Light Rail                1
# Name: count, Length: 765, dtype: int64

# %%
citibike_tripdata.drop(['start station id', 'end station id'], axis=1)
# Out:
#                        starttime                  stoptime  \
# 0       2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340
# 1       2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810
# 2       2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470
# 3       2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830
# 4       2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080
# ...                          ...                       ...
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620
#
#                      start station name  start station latitude  \
# 0          MacDougal St & Washington Sq               40.732264
# 1       Cadman Plaza West & Montague St               40.693830
# ...

# %%
print(citibike_tripdata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  object
#  1   stoptime                 300000 non-null  object
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
citibike_tripdata['age'] = 2018 - citibike_tripdata['birth year']
print(citibike_tripdata[citibike_tripdata['age'] > 60].shape[0])
# Out:
# 11837

# %%
citibike_tripdata['stoptime'] = pd.to_datetime(citibike_tripdata['stoptime'], dayfirst=False)
citibike_tripdata['starttime'] = pd.to_datetime(citibike_tripdata['starttime'], dayfirst=False)

# %%
citibike_tripdata['trip duration'] = citibike_tripdata['stoptime'] - citibike_tripdata['starttime']
display(citibike_tripdata)
# Out:
#                      starttime                stoptime  start station id  \
# 0      2018-09-01 00:00:05.269 2018-09-01 00:27:20.634             252.0
# 1      2018-09-01 00:00:11.281 2018-09-01 00:02:23.481             314.0
# 2      2018-09-01 00:00:20.649 2018-09-01 00:55:58.547            3142.0
# 3      2018-09-01 00:00:21.746 2018-09-01 00:07:38.583             308.0
# 4      2018-09-01 00:00:27.315 2018-09-01 02:21:25.308             345.0
# ...                        ...                     ...               ...
# 299995 2018-09-05 19:08:27.846 2018-09-05 19:15:51.494             494.0
# 299996 2018-09-05 19:08:28.370 2018-09-05 19:20:01.508            3016.0
# 299997 2018-09-05 19:08:27.509 2018-09-05 19:13:40.506            3686.0
# 299998 2018-09-05 19:08:29.230 2018-09-05 20:04:29.322             254.0
# 299999 2018-09-05 19:08:29.711 2018-09-05 19:12:14.762            3496.0
#
#                      start station name  start station latitude  \
# ...

# %%
citibike_tripdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   starttime                300000 non-null  datetime64[ns]
#  1   stoptime                 300000 non-null  datetime64[ns]
#  2   start station id         299831 non-null  float64
#  3   start station name       299831 non-null  object
#  4   start station latitude   300000 non-null  float64
#  5   start station longitude  300000 non-null  float64
#  6   end station id           299831 non-null  float64
#  7   end station name         299831 non-null  object
#  8   end station latitude     300000 non-null  float64
#  9   end station longitude    300000 non-null  float64
#  10  bikeid                   300000 non-null  int64
#  11  usertype                 300000 non-null  object
#  12  birth year               300000 non-null  int64
# ...

# %%
weekend = citibike_tripdata['starttime'].dt.dayofweek
citibike_tripdata['weekend'] = weekend.apply(lambda x: 0 if x < 5 else 1)
display(citibike_tripdata['weekend'].value_counts(normalize=True))
# Out:
# weekend
# 0    0.616217
# 1    0.383783
# Name: proportion, dtype: float64

# %%
time_of_day = citibike_tripdata['starttime'].dt.hour
def partofday(hour):
    if hour in range(0,7):
        return 'night'
    elif hour in range(7,13):
        return 'morning'
    elif hour in range(13,19):
        return 'day'
    elif hour in range(19,24):
        return 'evening'
citibike_tripdata['time_of_day'] = time_of_day.apply(partofday)
display(citibike_tripdata['time_of_day'].value_counts())
# Out:
# time_of_day
# day        143012
# morning     95530
# evening     46373
# night       15085
# Name: count, dtype: int64

# %%
print((citibike_tripdata[citibike_tripdata['time_of_day'] == 'day'].shape[0])/((citibike_tripdata[citibike_tripdata['time_of_day'] == 'night'].shape[0])))
# Out:
# 9.480411004308916

# %%
display(citibike_tripdata['time_of_day'].describe())
# Out:
# count     300000
# unique         4
# top          day
# freq      143012
# Name: time_of_day, dtype: object
