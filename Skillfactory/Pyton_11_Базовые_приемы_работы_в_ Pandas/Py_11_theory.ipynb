# %%
import pandas as pd
melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')
display(melb_data)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
#       2 melb_df.head()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
display(melb_df)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  int64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
melb_df['MeanRoomsArea'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsArea'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsArea, Length: 13580, dtype: float64

# %%
display(melb_df)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5      3067  ...    1     202.0
# ...

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
import pandas as pd

def delete_columns(df, col=[]):
    for colomn_name in col:
        if colomn_name in list(df.columns):
            df.drop([colomn_name],axis=1,inplace=True)
        else:
            pass
            return None
    return df.head()

customer_df = pd.DataFrame({'number': [0, 1, 2, 3, 4],'cust_id': [128, 1201, 9832, 4392, 7472],'cust_age': [13, 21, 19, 21, 60],'cust_sale': [0, 0, 0.2, 0.15, 0.3],'cust_year_birth': [2008, 2000, 2002, 2000, 1961],'cust_order': [1400, 14142, 900, 1240, 8430]})
# Out:
#    number  cust_id  cust_age  cust_year_birth  cust_order
# 0       0      128        13             2008        1400
# 1       1     1201        21             2000       14142
# 2       2     9832        19             2002         900
# 3       3     4392        21             2000        1240
# 4       4     7472        60             1961        8430

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
display(countries_df)
# Out:
#      country  population      area
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries_df.copy()
# Out:
#      country  population      area
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
countries_df['density_people'] = (countries_df['population']*1000000)/(countries_df['area'])
display(countries_df)
# Out:
#      country  population      area  density_people
# 0     Англия       56.29    133396      421.976671
# 1     Канада       38.05   9984670        3.810842
# 2        США      322.28   9826630       32.796595
# 3     Россия      146.24  17125191        8.539467
# 4    Украина       45.50    603628       75.377550
# 5   Беларусь        9.50    207600       45.761079
# 6  Казахстан       17.04   2724902        6.253436

# %%
print(round(countries_df['density_people'].mean(), 2))
# Out:
# 84.93

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int32
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# MonthSale
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: proportion, dtype: float64

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2012-01-01') 
display(delta_days)
# Out:
# 0       1798 days
# 1       1495 days
# 2       1889 days
# 3       1889 days
# 4       1616 days
#            ...
# 13575   2064 days
# 13576   2064 days
# 13577   2064 days
# 13578   2064 days
# 13579   2064 days
# Name: Date, Length: 13580, dtype: timedelta64[ns]

# %%
display(delta_days.dt.days)
# Out:
# 0        1798
# 1        1495
# 2        1889
# 3        1889
# 4        1616
#          ...
# 13575    2064
# 13576    2064
# 13577    2064
# 13578    2064
# 13579    2064
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YearBuilt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[170], line 1
# ...

# %%
melb_df = melb_df.drop('YearBuilt', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 melb_df = melb_df.drop('YearBuilt', axis=1)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
# ...

# %%
display(melb_df)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG       Date  Distance  Postcode  ...  BuildingArea  \
# 0        Biggin 2016-12-03       2.5      3067  ...         126.0
# ...

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
melb_df['WeekdaySale'].value_counts()
# Out:
# WeekdaySale
# 5    11759
# 6     1063
# 0      597
# 1      133
# 3       28
# Name: count, dtype: int64

# %%
weekend_count = melb_df['WeekdaySale'].head()
print(weekend_count)
# Out:
# 0    5
# 1    3
# 2    5
# 3    5
# 4    5
# Name: WeekdaySale, dtype: int32

# %%
def get_weekend(weekday):
     if weekday == 5 or weekday == 6:
         return 1
     else:
         return 0

# %%
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
display(melb_df['Weekend'])
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 13575    1
# 13576    1
# 13577    1
# 13578    1
# 13579    1
# Name: Weekend, Length: 13580, dtype: int64

# %%
display(melb_df['Weekend'].value_counts(normalize=True))
# Out:
# Weekend
# 1    0.944183
# 0    0.055817
# Name: proportion, dtype: float64

# %%
print(melb_df[melb_df['Weekend'] == 1]['Price'].mean())
# Out:
# 1081198.6406956792

# %%
display(melb_df)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG       Date  Distance  Postcode  ...  Lattitude  Longtitude  \
# ...

# %%
UFO = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv")

# %%
display(UFO)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
UFO['Time'] = pd.to_datetime(UFO['Time'])
display(UFO['Time'])
# Out:
# 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
#                 ...
# 18236   2000-12-31 23:00:00
# 18237   2000-12-31 23:00:00
# 18238   2000-12-31 23:45:00
# 18239   2000-12-31 23:45:00
# 18240   2000-12-31 23:59:00
# Name: Time, Length: 18241, dtype: datetime64[ns]

# %%
years_observed= UFO['Time'].dt.year
display(years_observed)
# Out:
# 0        1930
# 1        1930
# 2        1931
# 3        1931
# 4        1933
#          ...
# 18236    2000
# 18237    2000
# 18238    2000
# 18239    2000
# 18240    2000
# Name: Time, Length: 18241, dtype: int32

# %%
UFO['year'] = UFO['Time'].dt.year
years_obs = UFO['year'].value_counts()
years_obs.head(20)
# Out:
# year
# 1999    2774
# 2000    2635
# 1998    1743
# 1995    1344
# 1997    1237
# 1996     851
# 1994     406
# 1978     326
# 1975     312
# 1993     292
# 1976     281
# 1974     261
# 1977     258
# 1989     247
# 1992     245
# 1980     244
# 1979     237
# 1990     237
# 1988     232
# 1973     227
# Name: count, dtype: int64

# %%
datetime = UFO['Time'].dt.date
display(datetime)
# Out:
# 0        1930-06-01
# 1        1930-06-30
# 2        1931-02-15
# 3        1931-06-01
# 4        1933-04-18
#             ...
# 18236    2000-12-31
# 18237    2000-12-31
# 18238    2000-12-31
# 18239    2000-12-31
# 18240    2000-12-31
# Name: Time, Length: 18241, dtype: object

# %%
UFO['delta_days'] = UFO['Time'].dt.date

# %%
display(UFO)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                      Time  year  delta_days
# 0     1930-06-01 22:00:00  1930  1930-06-01
# 1     1930-06-30 20:00:00  1930  1930-06-30
# 2     1931-02-15 14:00:00  1931  1931-02-15
# ...

# %%
zxc = UFO[UFO["State"] == "NV"]['delta_days'].diff()
display(zxc)
# Out:
# 76            NaT
# 172     1678 days
# 565     2767 days
# 566        0 days
# 613      290 days
#            ...
# 17447     22 days
# 17567     14 days
# 17617      6 days
# 17890     32 days
# 18104     33 days
# Name: delta_days, Length: 284, dtype: timedelta64[ns]

# %%
display(zxc.dt.days.mean())
# Out:
# 68.92932862190813

# %%
display(melb_df['SellerG'].value_counts())
# Out:
# SellerG
# Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Barry            1011
# Ray               701
#                  ...
# Prowse              1
# Luxe                1
# Zahn                1
# Homes               1
# Point               1
# Name: count, Length: 268, dtype: int64

# %%
popular_seller = melb_df['SellerG'].value_counts().nlargest(49).index
print(popular_seller)
# Out:
# Index(['Nelson', 'Jellis', 'hockingstuart', 'Barry', 'Ray', 'Marshall',
#        'Buxton', 'Biggin', 'Brad', 'Fletchers', 'Woodards', 'Jas', 'Greg',
#        'McGrath', 'Sweeney', 'Noel', 'Miles', 'RT', 'Gary', 'Harcourts',
#        'Hodges', 'YPA', 'Stockdale', 'Village', 'Kay', 'Raine', 'Williams',
#        'Love', 'Douglas', 'Chisholm', 'RW', 'Rendina', 'HAR', 'O'Brien', 'C21',
#        'Collins', 'Cayzer', 'Eview', 'Purplebricks', 'Philip', 'Buckingham',
#        'Bells', 'Thomson', 'Nick', 'Alexkarbon', 'McDonald', 'Burnham',
#        'Moonee', 'LITTLE'],
#       dtype='object', name='SellerG')

# %%
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_seller else 'other')
display(melb_df)
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG       Date  Distance  Postcode  ...  Lattitude  Longtitude  \
# ...

# %%
print(round((melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min())/(melb_df[melb_df['SellerG'] == 'other']['Price'].min()), 2))
# Out:
# 1.3

# %%
print(melb_df.columns)
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount', 'MeanRoomsArea', 'AreaRatio',
#        'MonthSale', 'AgeBuilding', 'WeekdaySale', 'Weekend'],
#       dtype='object')

# %%
unique_list = []
for col in melb_df.columns:
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes) 
    unique_list.append(item) 
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
display(unique_counts)
# Out:
#       Column_Name  Num_Unique            Type
# 0         Weekend           2           int64
# 1            Type           3          object
# 2     WeekdaySale           5           int32
# 3          Method           5          object
# 4      Regionname           8          object
# 5           Rooms           9           int64
# 6        Bathroom           9           int64
# 7             Car          11           int64
# 8         Bedroom          12           int64
# 9       MonthSale          12           int32
# 10    CouncilArea          33          object
# 11        SellerG          50          object
# 12           Date          58  datetime64[ns]
# 13    AgeBuilding         152           int64
# 14       Postcode         198           int64
# 15       Distance         202         float64
# 16  Propertycount         311           int64
# 17         Suburb         314          object
# 18   BuildingArea         602         float64
# ...

# %%
print(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  CouncilArea    12211 non-null  object
#  16  Lattitude      13580 non-null  float64
# ...

# %%
display(melb_df['Suburb'].value_counts())
# Out:
# Suburb
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Sandhurst           1
# Bullengarook        1
# Croydon South       1
# Montrose            1
# Monbulk             1
# Name: count, Length: 314, dtype: int64

# %%
most_suburb = melb_df['Suburb'].value_counts().nlargest(119).index

# %%
melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in most_suburb else "other")

# %%
melb_df['Suburb'] = melb_df['Suburb'].astype('category')

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  category
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13580 non-null  int64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  CouncilArea    12211 non-null  object
#  16  Lattitude      13580 non-null  float64
# ...
